# %%
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'datapoint')
plt.title('This is my first plt')
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data point')
plt.plot(x_lin, y_hat, 'r-', label = "prediction")
plt.legend(loc = 0)
plt.show()

# %%
def mean_absolute_error(y, yp) :
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absoulte error is %.3f" % (MAE))
# Out:
# The Mean absoulte error is 12.032

# %%
def mean_square_error(y, yp) :
    mse = MSE = sum((y - yp)** 2) / len(y)

    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 206.491
